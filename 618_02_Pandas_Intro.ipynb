# %% [markdown]
# # SI 618: Data Manipulation and Analysis
# ## 02 - Introduction to pandas
# ### Dr. Chris Teplovs, School of Information, University of Michigan
# <small><a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a>This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ## Objectives:
# * Know how to manipulate Series and DataFrame
# * Draw a random sample of data
# * Select subset of data using boolean masking
# * Compute descriptive and summary statistics
# * Discretize continuous variables
# * Sort Series/DataFrame by index or column
# * Group data and calculate aggregate statistics
# * Use vectorized string methods
# * Make basic plots (scatter plot, histogram, bar chart, etc)
#
# ## Submission Instructions:
# Please turn in this Jupyter notebook file (both .ipynb and .html formats) on Canvas before you leave the classroom. Try to get through as much as you can.

# %% [markdown]
# ### IMPORTANT: Replace ```?``` in the following code with your uniqname.

# %%
MY_UNIQNAME = 'feiyi'

# %% [markdown]
# ## Preface
# This lab consists of Part 0, Part 1 and Part 2. Part 0 is an introduction to some Pandas basics. There are no points assocaited with Part 0 but we will be covering it in class. Part 1 is based on a survey dataset and Part 2 uses movies and cast data. We will guide you through Part 1, and let you work on Part 2 on your own.
#
# **Question 0 is worth 2 points.  Questions 1-12 are worth 1 point each.  Questions 13-23 are worth 2 points each.**

# %% [markdown]
# ### Question 0 (2 points, 0.5 points each):
# What is the output of pandas.DataFrame.describe()? (Chapter 5)
# Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution.
#
# What is the output of value_counts() work? (Chapter 5)
# Return a Series containing counts of unique values.
#
# What’s the difference between a series & a dataframe? (Chapter 5)
# Dataframe is composed of series.
# Series has one dimension. Dataframe is like a table.
#
# Explain what foo_bar.groupby(’A’).sum() returns (Data Wrangling with Python and Pandas 1.9)
# Group foo_bar by column 'A' and sum up other columns' values.

# %% [markdown]
# ## Part 0: Background

# %% [markdown]
# ![](assets/02.002.png)

# %% [markdown]
# ![](assets/02.003.png)

# %% [markdown]
# ![](assets/02.004.png)

# %% [markdown]
# * less looping over elements
# * lots of built-in functionality
# * a "paradigm shift"

# %% [markdown]
# ![](assets/02.005.png)

# %% [markdown]
# ![](assets/02.006.png)

# %% [markdown]
# ![](assets/02.007.png)

# %% [markdown]
# ![](assets/02.008.png)

# %% [markdown]
# ![](assets/02.009.png)

# %% [markdown]
# ![](assets/02.010.png)

# %% [markdown]
# ![](assets/02.011.png)

# %% [markdown]
# # Data structures
#
# We're all familiar with lists:

# %%
names = ["Charlotte", "Ingrid", "Ian", "Eric"]
scores = [80, 95, 85, 70]

# %% [markdown]
# Now let's say that we wanted to divide each of those scores by two and assign the results to another variable. Go ahead and write some code that does that... There are lots of ways to do this, so go ahead and write one way to do it (without importing any additional python packages) and assign the results to a
# variable called ```half```:

# %%
# insert code here
half = []
for i in scores:
    half.append(i/2)

# %% [markdown]
# If you followed the above instructions, the following cell block should print
# a list of floats that looks like ```
# [40.0, 47.5, 42.5, 35.0]```

# %%
half
# Out:
# [40.0, 47.5, 42.5, 35.0]

# %% [markdown]
# We can put data into an array structure that allows us to apply more powerful
# functions.  The data structure that we're interested in is called an ```ndarray``` and is from the ```numpy``` package:

# %%
import numpy as np
ascores = np.array(scores)

# %%
ascores
# Out:
# array([80, 95, 85, 70])

# %%
ahalf = ascores / 2

# %%
ahalf
# Out:
# array([40. , 47.5, 42.5, 35. ])

# %% [markdown]
# Numpy arrays are powerful, but they have some limitations:  they can only
# consist of one type of data (e.g. int), etc.  pandas provides two additional
# data structures that are built on numpy ndarrays.
#
# The first are Series.  Let's create a simple pandas Series and examine it:

# %%
import pandas as pd

# %%
sscores = pd.Series(scores,name='scores')

# %%
sscores
# Out:
# 0    80
# 1    95
# 2    85
# 3    70
# Name: scores, dtype: int64

# %% [markdown]
# So you see a couple of useful things: an index (0 to 3) and a data type (dtype), which in this case is an int64.
#
# **A Series is a one-dimensional ndarray with axis labels**

# %%
data = dict(zip(names,scores))

# %%
zip(names,scores)

# %%
data
# Out:
# {'Charlotte': 80, 'Ingrid': 95, 'Ian': 85, 'Eric': 70}

# %%
import pandas as pd

# %%
data
# Out:
# {'Charlotte': 80, 'Ingrid': 95, 'Ian': 85, 'Eric': 70}

# %%
sData = pd.Series(data=data,name='score')

# %%
sData
# Out:
# Charlotte    80
# Ingrid       95
# Ian          85
# Eric         70
# Name: score, dtype: int64

# %% [markdown]
# So Series are a bit friendlier than numpy arrays, but they're still only one-dimensional.  Keep in mind that our basic data abstraction is a table, which can
# be thought of as a two-dimensional array.  Let's go ahead and create a simple DataFrame with just one column:

# %%
pd.DataFrame(scores,index=names,columns=['score'])
# Out:
#            score
# Charlotte     80
# Ingrid        95
# Ian           85
# Eric          70

# %% [markdown]
# Let's return to the code we ran last time and walk though it just to make sure we understand it

# %%
df_names = pd.read_csv('data/names.csv')

# %% [markdown]
# Actually, that CSV file was created from a number of smaller CSV files.  Here's
# the code that will load the set of smaller CSV files:

# %%
years = range(1880, 2015)
pieces = []
for year in years:
    path = 'data/names/yob%d.csv' % year
    frame = pd.read_csv(path)
    frame['year'] = year
    pieces.append(frame)
df_names = pd.concat(pieces, ignore_index=True)

# %%
df_names.head()
# Out:
#      name gender  birth_count  year
# 0  Simeon      M           23  1880
# 1   Raoul      M            7  1880
# 2     Lou      M           14  1880
# 3    Myra      F           83  1880
# 4   Alois      M           10  1880

# %% [markdown]
# Let's discuss what just happened there.

# %% [markdown]
# # Part 1 (as a group): Mental Health Disorders In the Tech Workplace
# From https://www.kaggle.com/osmi/mental-health-in-tech-survey

# %% [markdown]
# ## Data Description
#
# This dataset is from a 2014 survey that measures attitudes towards mental health and frequency of mental health disorders in the tech workplace.

# %% [markdown]
# ## Metadata
#
# **Timestamp**
#
# **Age**
#
# **Gender**
#
# **Country**
#
# **state**: If you live in the United States, which state or territory do you live in?
#
# **self_employed**: Are you self-employed?
#
# **family_history**: Do you have a family history of mental illness?
#
# **treatment**: Have you sought treatment for a mental health condition?
#
# **work_interfere**: If you have a mental health condition, do you feel that it interferes with your work?
#
# **no_employees**: How many employees does your company or organization have?
#
# **remote_work**: Do you work remotely (outside of an office) at least 50% of the time?
#
# **tech_company**: Is your employer primarily a tech company/organization?
#
# **benefits**: Does your employer provide mental health benefits?
#
# **care_options**: Do you know the options for mental health care your employer provides?
#
# **wellness_program**: Has your employer ever discussed mental health as part of an employee wellness program?
#
# **seek_help**: Does your employer provide resources to learn more about mental health issues and how to seek help?
#
# **anonymity**: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
#
# **leave**: How easy is it for you to take medical leave for a mental health condition?
#
# **mental_health_consequence**: Do you think that discussing a mental health issue with your employer would have negative consequences?
#
# **phys_health_consequence**: Do you think that discussing a physical health issue with your employer would have negative consequences?
#
# **coworkers**: Would you be willing to discuss a mental health issue with your coworkers?
#
# **supervisor**: Would you be willing to discuss a mental health issue with your direct supervisor(s)?
#
# **mental_health_interview**: Would you bring up a mental health issue with a potential employer in an interview?
#
# **phys_health_interview**: Would you bring up a physical health issue with a potential employer in an interview?
#
# **mental_vs_physical**: Do you feel that your employer takes mental health as seriously as physical health?
#
# **obs_consequence**: Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?
#
# **comments**: Any additional notes or comments

# %% [markdown]
# Let's load the usual libraries and also ask for plots to be rendered inside the notebook:

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Then read the CSV file into a DataFrame:

# %%
df = pd.read_csv("data/survey.csv")

# %% [markdown]
# It's common to look at the resulting DataFrame using .head()

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees   ...     \
# 0             No       Yes          Often            6-25   ...
# 1             No        No         Rarely  More than 1000   ...
# 2             No        No         Rarely            6-25   ...
# 3            Yes       Yes          Often          26-100   ...
# 4             No        No          Never         100-500   ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# If you want to look at a random sample, you can use .sample()

# %%
df.sample(5)
# Out:
#                 Timestamp  Age       Gender        Country state  \
# 1034  2014-08-29 11:01:41   36            M  United States    MN
# 1178  2014-09-26 08:45:56   40            m          China   NaN
# 451   2014-08-27 15:53:59   40  Genderqueer  United States    VA
# 922   2014-08-28 20:31:02   28         Male  United States    CA
# 522   2014-08-27 17:15:25   35         Male  United States    AZ
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 1034            No             No        No          Never         100-500
# 1178           Yes             No        No      Sometimes             1-5
# 451             No            Yes        No          Never  More than 1000
# 922             No            Yes       Yes      Sometimes          26-100
# 522             No             No        No            NaN  More than 1000
#
#        ...             leave mental_health_consequence  \
# 1034   ...        Don't know                       Yes
# 1178   ...     Somewhat easy                        No
# 451    ...        Don't know                       Yes
# 922    ...        Don't know                     Maybe
# 522    ...        Don't know                     Maybe
#
#      phys_health_consequence     coworkers    supervisor  \
# 1034                   Maybe            No            No
# 1178                      No  Some of them  Some of them
# 451                    Maybe            No  Some of them
# 922                    Maybe  Some of them  Some of them
# 522                    Maybe            No            No
#
#      mental_health_interview phys_health_interview mental_vs_physical  \
# 1034                      No                 Maybe         Don't know
# 1178                   Maybe                 Maybe         Don't know
# 451                       No                 Maybe                Yes
# 922                       No                    No                Yes
# 522                       No                    No                 No
#
#      obs_consequence comments
# 1034             Yes      NaN
# 1178              No      NaN
# 451               No      NaN
# 922               No      NaN
# 522               No      NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Finally, you can get some basic information about the size and shape of the DataFrame:

# %%
print("The number of rows of the dataset is: ", len(df))
print("The number of columns of the dataset is: ", len(df.columns))
print("The shape of the dataset is: ", df.shape)
# Out:
# The number of rows of the dataset is:  1259
# The number of columns of the dataset is:  27
# The shape of the dataset is:  (1259, 27)

# %% [markdown]
# You can list the columns:

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %% [markdown]
# And you can extract one or more columns.  The following pair of
# commands do exactly the same thing:

# %%
print(df['Country'])
# Out:
# 0        United States
# 1        United States
# 2               Canada
# 3       United Kingdom
# 4        United States
# 5        United States
# 6        United States
# 7               Canada
# 8        United States
# 9               Canada
# 10       United States
# 11            Bulgaria
# 12       United States
# 13       United States
# 14              Canada
# 15       United States
# 16      United Kingdom
# 17       United States
# 18       United States
# 19              France
# 20       United States
# 21       United States
# 22       United States
# 23       United States
# 24       United States
# 25       United States
# 26       United States
# 27       United States
# 28       United States
# 29      United Kingdom
#              ...
# 1229            Greece
# 1230    United Kingdom
# 1231    United Kingdom
# 1232    United Kingdom
# 1233    United Kingdom
# 1234    United Kingdom
# 1235            Canada
# 1236     United States
# 1237           Ireland
# 1238     United States
# 1239       Netherlands
# 1240           Germany
# 1241            Poland
# 1242           Ireland
# 1243     United States
# 1244    United Kingdom
# 1245         Australia
# 1246     United States
# 1247           Finland
# 1248     United States
# 1249     United States
# 1250     United States
# 1251      South Africa
# 1252     United States
# 1253     United States
# 1254    United Kingdom
# 1255     United States
# 1256     United States
# 1257     United States
# 1258     United States
# Name: Country, Length: 1259, dtype: object

# %%
country_state = df[['Country','state']]
country_state.head()
# Out:
#           Country state
# 0   United States    IL
# 1   United States    IN
# 2          Canada   NaN
# 3  United Kingdom   NaN
# 4   United States    TX

# %% [markdown]
# ## Extracting rows

# %%
df.iloc[0]
# Out:
# Timestamp                    2014-08-27 11:29:31
# Age                                           37
# Gender                                    Female
# Country                            United States
# state                                         IL
# self_employed                                NaN
# family_history                                No
# treatment                                    Yes
# work_interfere                             Often
# no_employees                                6-25
# remote_work                                   No
# tech_company                                 Yes
# benefits                                     Yes
# care_options                            Not sure
# wellness_program                              No
# seek_help                                    Yes
# anonymity                                    Yes
# leave                              Somewhat easy
# mental_health_consequence                     No
# phys_health_consequence                       No
# coworkers                           Some of them
# supervisor                                   Yes
# mental_health_interview                       No
# phys_health_interview                      Maybe
# mental_vs_physical                           Yes
# obs_consequence                               No
# comments                                     NaN
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Timestamp                    2014-08-27 11:29:31
# Age                                           37
# Gender                                    Female
# Country                            United States
# state                                         IL
# self_employed                                NaN
# family_history                                No
# treatment                                    Yes
# work_interfere                             Often
# no_employees                                6-25
# remote_work                                   No
# tech_company                                 Yes
# benefits                                     Yes
# care_options                            Not sure
# wellness_program                              No
# seek_help                                    Yes
# anonymity                                    Yes
# leave                              Somewhat easy
# mental_health_consequence                     No
# phys_health_consequence                       No
# coworkers                           Some of them
# supervisor                                   Yes
# mental_health_interview                       No
# phys_health_interview                      Maybe
# mental_vs_physical                           Yes
# obs_consequence                               No
# comments                                     NaN
# Name: 0, dtype: object

# %%
df_gender = df.set_index('Gender')

# %%
df_gender.loc['Male']
# Out:
#                   Timestamp  Age         Country state self_employed  \
# Gender
# Male    2014-08-27 11:29:44   32          Canada   NaN           NaN
# Male    2014-08-27 11:29:46   31  United Kingdom   NaN           NaN
# Male    2014-08-27 11:30:22   31   United States    TX           NaN
# Male    2014-08-27 11:31:22   33   United States    TN           NaN
# Male    2014-08-27 11:32:43   23          Canada   NaN           NaN
# Male    2014-08-27 11:32:44   31   United States    OH           NaN
# Male    2014-08-27 11:33:26   36   United States    CT           NaN
# Male    2014-08-27 11:33:57   27          Canada   NaN           NaN
# Male    2014-08-27 11:34:20   23  United Kingdom   NaN           NaN
# Male    2014-08-27 11:34:37   32   United States    TN           NaN
# Male    2014-08-27 11:35:08   36          France   NaN           Yes
# Male    2014-08-27 11:35:12   29   United States    NY            No
# Male    2014-08-27 11:35:48   46   United States    MA            No
# Male    2014-08-27 11:36:24   41   United States    IA            No
# Male    2014-08-27 11:38:18   37  United Kingdom   NaN            No
# Male    2014-08-27 11:39:03   32  United Kingdom   NaN            No
# Male    2014-08-27 11:38:55   31   United States    PA           Yes
# Male    2014-08-27 11:39:36   42   United States    WA            No
# Male    2014-08-27 11:41:17   27   United States    NY            No
# Male    2014-08-27 11:41:37   29          Canada   NaN            No
# Male    2014-08-27 11:41:50   38        Portugal   NaN            No
# Male    2014-08-27 11:42:25   24  United Kingdom   NaN            No
# Male    2014-08-27 11:42:31   35   United States    MI            No
# Male    2014-08-27 11:43:07   27          Canada   NaN            No
# Male    2014-08-27 11:43:10   18     Netherlands   NaN            No
# Male    2014-08-27 11:43:22   30   United States    IN            No
# Male    2014-08-27 11:43:45   28  United Kingdom   NaN            No
# Male    2014-08-27 11:43:48   34   United States    TN            No
# Male    2014-08-27 11:45:32   33   United States    UT            No
# Male    2014-08-27 11:45:51   32   United States    TN            No
# ...                     ...  ...             ...   ...           ...
# Male    2015-02-21 04:41:28   32   United States    TX            No
# Male    2015-02-21 04:55:11   28       Australia   NaN            No
# Male    2015-02-21 05:34:27   31          Brazil   NaN           Yes
# Male    2015-02-21 05:55:13   24  United Kingdom   NaN            No
# Male    2015-02-21 05:55:17   34         Ireland   NaN            No
# Male    2015-02-21 06:19:41   34  United Kingdom   NaN            No
# Male    2015-02-21 08:21:36   23   United States    TX            No
# Male    2015-02-21 08:54:40   33  Czech Republic   NaN            No
# Male    2015-02-21 09:19:12   31     Philippines   NaN            No
# Male    2015-02-21 09:22:23   33   United States    FL            No
# Male    2015-02-21 09:30:14   27  United Kingdom   NaN            No
# Male    2015-02-21 09:48:13   38   United States    TX            No
# Male    2015-02-21 10:00:50   46   United States    CA            No
# Male    2015-02-21 17:19:18   39     Netherlands   NaN            No
# Male    2015-02-21 18:59:05   25   United States    MN            No
# Male    2015-02-22 02:40:32   39          Greece   NaN            No
# Male    2015-02-24 09:00:56   25  United Kingdom   NaN            No
# Male    2015-02-24 09:13:49   23  United Kingdom   NaN            No
# Male    2015-02-24 09:18:25   23          Canada   NaN            No
# Male    2015-02-24 10:32:32   60   United States    CA            No
# Male    2015-04-02 15:47:43   28   United States    TN            No
# Male    2015-04-11 14:35:22   31          Poland   NaN           Yes
# Male    2015-04-23 14:03:51   28         Ireland   NaN            No
# Male    2015-05-06 10:14:50   22       Australia   NaN            No
# Male    2015-05-06 16:55:58   32   United States    OR            No
# Male    2015-07-27 23:25:34   30   United States    CA           Yes
# Male    2015-08-17 09:38:35   36    South Africa   NaN            No
# Male    2015-08-25 19:59:38   36   United States    UT            No
# Male    2015-09-26 01:07:35   32   United States    IL            No
# Male    2016-02-01 23:04:31   25   United States    IL            No
#
#        family_history treatment work_interfere    no_employees remote_work  \
# Gender
# Male               No        No         Rarely            6-25          No
# Male              Yes       Yes          Often          26-100          No
# Male               No        No          Never         100-500         Yes
# Male              Yes        No      Sometimes            6-25          No
# Male               No        No          Never          26-100          No
# Male               No       Yes      Sometimes            6-25         Yes
# Male              Yes        No          Never        500-1000          No
# Male               No        No          Never            6-25          No
# Male               No       Yes      Sometimes          26-100         Yes
# Male               No       Yes      Sometimes            6-25          No
# Male              Yes        No            NaN            6-25         Yes
# Male              Yes       Yes      Sometimes         100-500          No
# Male               No       Yes          Often          26-100         Yes
# Male               No       Yes          Never  More than 1000          No
# Male               No        No      Sometimes            6-25          No
# Male               No        No          Never            6-25         Yes
# Male              Yes        No         Rarely             1-5         Yes
# Male              Yes       Yes      Sometimes          26-100         Yes
# Male               No       Yes         Rarely            6-25          No
# Male               No        No         Rarely             1-5          No
# Male               No        No            NaN         100-500          No
# Male               No       Yes      Sometimes            6-25          No
# Male               No        No            NaN  More than 1000         Yes
# Male              Yes       Yes      Sometimes             1-5          No
# Male               No        No          Often            6-25          No
# Male               No       Yes      Sometimes          26-100          No
# Male               No        No            NaN          26-100          No
# Male               No        No            NaN            6-25          No
# Male               No        No            NaN         100-500         Yes
# Male               No        No          Never             1-5         Yes
# ...               ...       ...            ...             ...         ...
# Male               No       Yes          Often          26-100         Yes
# Male               No       Yes          Often         100-500         Yes
# Male               No       Yes            NaN             1-5          No
# Male               No        No            NaN         100-500          No
# Male              Yes       Yes          Never             1-5         Yes
# Male              Yes        No          Often          26-100         Yes
# Male               No       Yes      Sometimes             1-5          No
# Male              Yes        No          Often         100-500          No
# Male               No        No      Sometimes  More than 1000          No
# Male               No       Yes          Often          26-100         Yes
# Male               No        No         Rarely  More than 1000         Yes
# Male               No       Yes      Sometimes  More than 1000         Yes
# Male              Yes       Yes          Often          26-100          No
# Male               No        No            NaN  More than 1000          No
# Male              Yes       Yes      Sometimes          26-100          No
# Male               No        No            NaN            6-25         Yes
# Male              Yes       Yes      Sometimes  More than 1000          No
# Male               No       Yes         Rarely            6-25          No
# Male               No       Yes          Often          26-100          No
# Male               No       Yes          Often  More than 1000         Yes
# Male              Yes       Yes          Often  More than 1000          No
# Male               No       Yes          Often            6-25         Yes
# Male               No       Yes         Rarely          26-100          No
# Male              Yes       Yes          Often         100-500          No
# Male               No        No          Never         100-500          No
# Male              Yes       Yes          Often          26-100          No
# Male              Yes       Yes          Often         100-500          No
# Male              Yes        No         Rarely  More than 1000          No
# Male              Yes       Yes          Often          26-100         Yes
# Male              Yes       Yes      Sometimes          26-100          No
#
#                               ...                                       leave  \
# Gender                        ...
# Male                          ...                          Somewhat difficult
# Male                          ...                          Somewhat difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                                   Very easy
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                          Somewhat difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                              Very difficult
# Male                          ...                                  Don't know
# Male                          ...                          Somewhat difficult
# Male                          ...                                   Very easy
# Male                          ...                                   Very easy
# Male                          ...                                   Very easy
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                          Somewhat difficult
# Male                          ...                              Very difficult
# Male                          ...                          Somewhat difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# ...                           ...                                         ...
# Male                          ...                              Very difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                                   Very easy
# Male                          ...                               Somewhat easy
# Male                          ...                              Very difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                   Very easy
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                                   Very easy
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                               Somewhat easy
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                               Somewhat easy
# Male                          ...                          Somewhat difficult
# Male                          ...                                  Don't know
#
#        mental_health_consequence phys_health_consequence     coworkers  \
# Gender
# Male                          No                      No           Yes
# Male                         Yes                     Yes  Some of them
# Male                          No                      No  Some of them
# Male                          No                      No           Yes
# Male                          No                      No           Yes
# Male                          No                      No  Some of them
# Male                          No                      No           Yes
# Male                          No                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                          No                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No            No
# Male                         Yes                   Maybe  Some of them
# Male                         Yes                     Yes  Some of them
# Male                         Yes                      No            No
# Male                       Maybe                      No  Some of them
# Male                          No                      No           Yes
# Male                         Yes                   Maybe  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                   Maybe  Some of them
# Male                         Yes                     Yes  Some of them
# Male                       Maybe                      No  Some of them
# Male                         Yes                   Maybe            No
# Male                          No                      No            No
# Male                          No                   Maybe  Some of them
# Male                          No                      No           Yes
# Male                          No                      No  Some of them
# Male                       Maybe                      No  Some of them
# ...                          ...                     ...           ...
# Male                         Yes                   Maybe  Some of them
# Male                         Yes                      No            No
# Male                          No                      No           Yes
# Male                       Maybe                   Maybe  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                   Maybe  Some of them
# Male                          No                      No  Some of them
# Male                         Yes                     Yes  Some of them
# Male                       Maybe                      No  Some of them
# Male                          No                      No  Some of them
# Male                          No                      No           Yes
# Male                       Maybe                      No  Some of them
# Male                       Maybe                   Maybe            No
# Male                         Yes                      No  Some of them
# Male                         Yes                      No            No
# Male                          No                      No           Yes
# Male                          No                      No           Yes
# Male                       Maybe                      No           Yes
# Male                       Maybe                   Maybe  Some of them
# Male                         Yes                   Maybe  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No            No
# Male                       Maybe                   Maybe            No
# Male                          No                      No            No
# Male                          No                      No  Some of them
# Male                          No                      No  Some of them
# Male                       Maybe                   Maybe  Some of them
# Male                          No                      No  Some of them
# Male                       Maybe                      No  Some of them
#
#           supervisor mental_health_interview phys_health_interview  \
# Gender
# Male             Yes                     Yes                   Yes
# Male              No                   Maybe                 Maybe
# Male             Yes                     Yes                   Yes
# Male             Yes                      No                 Maybe
# Male             Yes                   Maybe                 Maybe
# Male             Yes                      No                    No
# Male             Yes                      No                    No
# Male    Some of them                   Maybe                   Yes
# Male              No                   Maybe                 Maybe
# Male             Yes                      No                    No
# Male    Some of them                   Maybe                 Maybe
# Male    Some of them                      No                    No
# Male             Yes                      No                 Maybe
# Male              No                      No                   Yes
# Male              No                      No                 Maybe
# Male    Some of them                      No                 Maybe
# Male              No                      No                    No
# Male    Some of them                   Maybe                   Yes
# Male             Yes                   Maybe                 Maybe
# Male              No                      No                    No
# Male    Some of them                      No                 Maybe
# Male              No                      No                   Yes
# Male              No                      No                 Maybe
# Male              No                      No                    No
# Male    Some of them                      No                    No
# Male              No                      No                 Maybe
# Male             Yes                   Maybe                   Yes
# Male             Yes                   Maybe                   Yes
# Male             Yes                   Maybe                 Maybe
# Male             Yes                      No                    No
# ...              ...                     ...                   ...
# Male              No                      No                    No
# Male              No                      No                 Maybe
# Male             Yes                      No                 Maybe
# Male             Yes                      No                 Maybe
# Male             Yes                      No                    No
# Male             Yes                   Maybe                   Yes
# Male             Yes                      No                    No
# Male             Yes                   Maybe                 Maybe
# Male              No                      No                 Maybe
# Male              No                      No                 Maybe
# Male             Yes                      No                    No
# Male             Yes                      No                    No
# Male              No                      No                    No
# Male    Some of them                      No                    No
# Male    Some of them                      No                 Maybe
# Male              No                      No                    No
# Male             Yes                     Yes                   Yes
# Male             Yes                      No                 Maybe
# Male    Some of them                      No                    No
# Male              No                      No                 Maybe
# Male             Yes                      No                    No
# Male              No                      No                    No
# Male              No                      No                 Maybe
# Male             Yes                      No                 Maybe
# Male    Some of them                   Maybe                   Yes
# Male             Yes                   Maybe                 Maybe
# Male             Yes                      No                   Yes
# Male    Some of them                      No                    No
# Male             Yes                      No                    No
# Male              No                      No                    No
#
#        mental_vs_physical obs_consequence  \
# Gender
# Male                   No              No
# Male                   No             Yes
# Male           Don't know              No
# Male           Don't know              No
# Male                  Yes              No
# Male           Don't know              No
# Male           Don't know              No
# Male                  Yes              No
# Male                   No              No
# Male                   No              No
# Male           Don't know              No
# Male                   No              No
# Male                   No              No
# Male           Don't know              No
# Male                   No              No
# Male                   No              No
# Male                   No             Yes
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male                   No              No
# Male                   No             Yes
# Male           Don't know              No
# Male                  Yes              No
# Male                   No              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# ...                   ...             ...
# Male           Don't know              No
# Male                   No              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male                  Yes              No
# Male                   No              No
# Male           Don't know             Yes
# Male                   No             Yes
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male                   No              No
# Male                  Yes              No
# Male           Don't know              No
# Male           Don't know              No
# Male                  Yes              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male                   No             Yes
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know             Yes
# Male           Don't know              No
# Male                  Yes              No
# Male                  Yes              No
# Male           Don't know              No
# Male                  Yes              No
# Male           Don't know              No
#
#                                                  comments
# Gender
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    I'm not on my company's health insurance which...
# Male                                                  NaN
# Male    My company does provide healthcare but not to ...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    I selected my current employer based on its po...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# ...                                                   ...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    I openly discuss my mental health struggles. I...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    I work at a large university with a track reco...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    In australia all organisations of a certain si...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
#
# [615 rows x 26 columns]

# %%
df.iloc['Gender'] # generates error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-5291e24a4fb8> in <module>()
# ----> 1 df.iloc['Gender'] # generates error
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2093         # a single integer
#    2094         else:
# -> 2095             key = self._convert_scalar_indexer(key, axis)
#    2096
#    2097             if not is_integer(key):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _convert_scalar_indexer(self, key, axis)
#     259         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     260         # a scalar
# --> 261         return ax._convert_scalar_indexer(key, kind=self.name)
#     262
#     263     def _convert_slice_indexer(self, key, axis):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\numeric.py in _convert_scalar_indexer(self, key, kind)
#     185             key = self._maybe_cast_indexer(key)
#     186         return (super(Int64Index, self)
# --> 187                 ._convert_scalar_indexer(key, kind=kind))
#     188
#     189     def _wrap_joined_index(self, joined, other):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in _convert_scalar_indexer(self, key, kind)
#    1635
#    1636         if kind == 'iloc':
# -> 1637             return self._validate_indexer('positional', key, kind)
#    1638
#    1639         if len(self) and not isinstance(self, ABCMultiIndex,):
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    4126             pass
#    4127         elif kind in ['iloc', 'getitem']:
# -> 4128             self._invalid_indexer(form, key)
#    4129         return key
#    4130
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    1846                         "indexers [{key}] of {kind}".format(
#    1847                             form=form, klass=type(self), key=key,
# -> 1848                             kind=type(key)))
#    1849
#    1850     def get_duplicates(self):
#
# TypeError: cannot do positional indexing on <class 'pandas.core.indexes.range.RangeIndex'> with these indexers [Gender] of <class 'str'>

# %%
df.iloc[0]
# Out:
# Timestamp                    2014-08-27 11:29:31
# Age                                           37
# Gender                                    Female
# Country                            United States
# state                                         IL
# self_employed                                NaN
# family_history                                No
# treatment                                    Yes
# work_interfere                             Often
# no_employees                                6-25
# remote_work                                   No
# tech_company                                 Yes
# benefits                                     Yes
# care_options                            Not sure
# wellness_program                              No
# seek_help                                    Yes
# anonymity                                    Yes
# leave                              Somewhat easy
# mental_health_consequence                     No
# phys_health_consequence                       No
# coworkers                           Some of them
# supervisor                                   Yes
# mental_health_interview                       No
# phys_health_interview                      Maybe
# mental_vs_physical                           Yes
# obs_consequence                               No
# comments                                     NaN
# Name: 0, dtype: object

# %% [markdown]
# ## Sorting
# You can use either sort_values() or sort_index():

# %%
df_sorted = df.sort_values('Age')
df_sorted.head(10)
# Out:
#                 Timestamp   Age              Gender         Country state  \
# 715   2014-08-28 10:07:53 -1726                male  United Kingdom   NaN
# 143   2014-08-27 12:39:14   -29                Male   United States    MN
# 1127  2014-08-30 20:55:11    -1                   p   United States    AL
# 734   2014-08-28 10:35:55     5                Male   United States    OH
# 989   2014-08-29 09:10:58     8  A little about you    Bahamas, The    IL
# 1090  2014-08-29 17:26:15    11                male   United States    OH
# 282   2014-08-27 14:10:15    18                male   United States    TX
# 287   2014-08-27 14:11:55    18                Male   United States    WA
# 43    2014-08-27 11:43:10    18                Male     Netherlands   NaN
# 482   2014-08-27 16:19:05    18              Female  United Kingdom   NaN
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 715             No             No       Yes      Sometimes          26-100
# 143             No             No        No            NaN  More than 1000
# 1127           Yes            Yes       Yes          Often             1-5
# 734             No             No        No            NaN         100-500
# 989            Yes            Yes       Yes          Often             1-5
# 1090           Yes             No        No          Never             1-5
# 282             No             No       Yes      Sometimes            6-25
# 287             No             No        No          Never          26-100
# 43              No             No        No          Often            6-25
# 482             No            Yes       Yes      Sometimes             1-5
#
#                             ...                                       leave  \
# 715                         ...                          Somewhat difficult
# 143                         ...                                  Don't know
# 1127                        ...                                   Very easy
# 734                         ...                               Somewhat easy
# 989                         ...                                   Very easy
# 1090                        ...                                   Very easy
# 282                         ...                                  Don't know
# 287                         ...                                   Very easy
# 43                          ...                          Somewhat difficult
# 482                         ...                                  Don't know
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 715                        Yes                      No            No
# 143                         No                      No  Some of them
# 1127                       Yes                     Yes           Yes
# 734                         No                      No           Yes
# 989                        Yes                     Yes           Yes
# 1090                        No                      No  Some of them
# 282                        Yes                      No            No
# 287                         No                      No  Some of them
# 43                         Yes                   Maybe            No
# 482                      Maybe                   Maybe  Some of them
#
#         supervisor mental_health_interview phys_health_interview  \
# 715             No                      No                 Maybe
# 143            Yes                      No                    No
# 1127           Yes                     Yes                   Yes
# 734            Yes                      No                    No
# 989            Yes                     Yes                   Yes
# 1090  Some of them                      No                 Maybe
# 282             No                      No                 Maybe
# 287   Some of them                      No                 Maybe
# 43    Some of them                      No                    No
# 482   Some of them                   Maybe                 Maybe
#
#      mental_vs_physical obs_consequence  \
# 715          Don't know              No
# 143          Don't know              No
# 1127                Yes             Yes
# 734                 Yes              No
# 989                 Yes             Yes
# 1090                Yes              No
# 282          Don't know              No
# 287                 Yes              No
# 43                   No              No
# 482          Don't know              No
#
#                                                comments
# 715                                                 NaN
# 143                                                 NaN
# 1127                                 password: testered
# 734   We had a developer suffer from depression and ...
# 989
# 1090                                                NaN
# 282                                                 NaN
# 287                                                 NaN
# 43                                                  NaN
# 482                               I don't have a job :D
#
# [10 rows x 27 columns]

# %% [markdown]
# ## Filtering using Boolean Masking

# %%
df.Age
# Out:
# 0       37
# 1       44
# 2       32
# 3       31
# 4       31
# 5       33
# 6       35
# 7       39
# 8       42
# 9       23
# 10      31
# 11      29
# 12      42
# 13      36
# 14      27
# 15      29
# 16      23
# 17      32
# 18      46
# 19      36
# 20      29
# 21      31
# 22      46
# 23      41
# 24      33
# 25      35
# 26      33
# 27      35
# 28      34
# 29      37
#         ..
# 1229    39
# 1230    23
# 1231    24
# 1232    25
# 1233    23
# 1234    24
# 1235    23
# 1236    60
# 1237    28
# 1238    28
# 1239    30
# 1240    31
# 1241    31
# 1242    28
# 1243    43
# 1244    32
# 1245    22
# 1246    32
# 1247    36
# 1248    41
# 1249    30
# 1250    30
# 1251    36
# 1252    29
# 1253    36
# 1254    26
# 1255    32
# 1256    34
# 1257    46
# 1258    25
# Name: Age, Length: 1259, dtype: int64

# %%
df['Age'] > 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#         ...
# 1229    True
# 1230    True
# 1231    True
# 1232    True
# 1233    True
# 1234    True
# 1235    True
# 1236    True
# 1237    True
# 1238    True
# 1239    True
# 1240    True
# 1241    True
# 1242    True
# 1243    True
# 1244    True
# 1245    True
# 1246    True
# 1247    True
# 1248    True
# 1249    True
# 1250    True
# 1251    True
# 1252    True
# 1253    True
# 1254    True
# 1255    True
# 1256    True
# 1257    True
# 1258    True
# Name: Age, Length: 1259, dtype: bool

# %%
df[df['Age'] > 0]
# Out:
#                 Timestamp  Age  \
# 0     2014-08-27 11:29:31   37
# 1     2014-08-27 11:29:37   44
# 2     2014-08-27 11:29:44   32
# 3     2014-08-27 11:29:46   31
# 4     2014-08-27 11:30:22   31
# 5     2014-08-27 11:31:22   33
# 6     2014-08-27 11:31:50   35
# 7     2014-08-27 11:32:05   39
# 8     2014-08-27 11:32:39   42
# 9     2014-08-27 11:32:43   23
# 10    2014-08-27 11:32:44   31
# 11    2014-08-27 11:32:49   29
# 12    2014-08-27 11:33:23   42
# 13    2014-08-27 11:33:26   36
# 14    2014-08-27 11:33:57   27
# 15    2014-08-27 11:34:00   29
# 16    2014-08-27 11:34:20   23
# 17    2014-08-27 11:34:37   32
# 18    2014-08-27 11:34:53   46
# 19    2014-08-27 11:35:08   36
# 20    2014-08-27 11:35:12   29
# 21    2014-08-27 11:35:24   31
# 22    2014-08-27 11:35:48   46
# 23    2014-08-27 11:36:24   41
# 24    2014-08-27 11:36:48   33
# 25    2014-08-27 11:37:08   35
# 26    2014-08-27 11:37:23   33
# 27    2014-08-27 11:37:59   35
# 28    2014-08-27 11:38:12   34
# 29    2014-08-27 11:38:18   37
# ...                   ...  ...
# 1229  2015-02-22 02:40:32   39
# 1230  2015-02-24 08:54:35   23
# 1231  2015-02-24 08:58:08   24
# 1232  2015-02-24 09:00:56   25
# 1233  2015-02-24 09:13:49   23
# 1234  2015-02-24 09:15:13   24
# 1235  2015-02-24 09:18:25   23
# 1236  2015-02-24 10:32:32   60
# 1237  2015-02-26 05:44:16   28
# 1238  2015-04-02 15:47:43   28
# 1239  2015-04-04 11:22:05   30
# 1240  2015-04-06 14:58:29   31
# 1241  2015-04-11 14:35:22   31
# 1242  2015-04-23 14:03:51   28
# 1243  2015-05-05 14:22:18   43
# 1244  2015-05-05 15:16:25   32
# 1245  2015-05-06 10:14:50   22
# 1246  2015-05-06 16:55:58   32
# 1247  2015-05-07 10:08:50   36
# 1248  2015-06-25 12:24:31   41
# 1249  2015-07-22 18:57:54   30
# 1250  2015-07-27 23:25:34   30
# 1251  2015-08-17 09:38:35   36
# 1252  2015-08-20 16:52:09   29
# 1253  2015-08-25 19:59:38   36
# 1254  2015-09-12 11:17:21   26
# 1255  2015-09-26 01:07:35   32
# 1256  2015-11-07 12:36:58   34
# 1257  2015-11-30 21:25:06   46
# 1258  2016-02-01 23:04:31   25
#
#                                               Gender         Country state  \
# 0                                             Female   United States    IL
# 1                                                  M   United States    IN
# 2                                               Male          Canada   NaN
# 3                                               Male  United Kingdom   NaN
# 4                                               Male   United States    TX
# 5                                               Male   United States    TN
# 6                                             Female   United States    MI
# 7                                                  M          Canada   NaN
# 8                                             Female   United States    IL
# 9                                               Male          Canada   NaN
# 10                                              Male   United States    OH
# 11                                              male        Bulgaria   NaN
# 12                                            female   United States    CA
# 13                                              Male   United States    CT
# 14                                              Male          Canada   NaN
# 15                                            female   United States    IL
# 16                                              Male  United Kingdom   NaN
# 17                                              Male   United States    TN
# 18                                              male   United States    MD
# 19                                              Male          France   NaN
# 20                                              Male   United States    NY
# 21                                              male   United States    NC
# 22                                              Male   United States    MA
# 23                                              Male   United States    IA
# 24                                              male   United States    CA
# 25                                              male   United States    TN
# 26                                              male   United States    TN
# 27                                            Female   United States    CA
# 28                                              male   United States    OH
# 29                                              Male  United Kingdom   NaN
# ...                                              ...             ...   ...
# 1229                                            Male          Greece   NaN
# 1230                                          Female  United Kingdom   NaN
# 1231                                         Cis Man  United Kingdom   NaN
# 1232                                            Male  United Kingdom   NaN
# 1233                                            Male  United Kingdom   NaN
# 1234  ostensibly male, unsure what that really means  United Kingdom   NaN
# 1235                                            Male          Canada   NaN
# 1236                                            Male   United States    CA
# 1237                                            male         Ireland   NaN
# 1238                                            Male   United States    TN
# 1239                                            male     Netherlands   NaN
# 1240                                            male         Germany   NaN
# 1241                                            Male          Poland   NaN
# 1242                                            Male         Ireland   NaN
# 1243                                               f   United States    FL
# 1244                                          female  United Kingdom   NaN
# 1245                                            Male       Australia   NaN
# 1246                                            Male   United States    OR
# 1247                                            male         Finland   NaN
# 1248                                          Female   United States    WA
# 1249                                               M   United States    CA
# 1250                                            Male   United States    CA
# 1251                                            Male    South Africa   NaN
# 1252                                            male   United States    NC
# 1253                                            Male   United States    UT
# 1254                                            male  United Kingdom   NaN
# 1255                                            Male   United States    IL
# 1256                                            male   United States    CA
# 1257                                               f   United States    NC
# 1258                                            Male   United States    IL
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 0              NaN             No       Yes          Often            6-25
# 1              NaN             No        No         Rarely  More than 1000
# 2              NaN             No        No         Rarely            6-25
# 3              NaN            Yes       Yes          Often          26-100
# 4              NaN             No        No          Never         100-500
# 5              NaN            Yes        No      Sometimes            6-25
# 6              NaN            Yes       Yes      Sometimes             1-5
# 7              NaN             No        No          Never             1-5
# 8              NaN            Yes       Yes      Sometimes         100-500
# 9              NaN             No        No          Never          26-100
# 10             NaN             No       Yes      Sometimes            6-25
# 11             NaN             No        No          Never         100-500
# 12             NaN            Yes       Yes      Sometimes          26-100
# 13             NaN            Yes        No          Never        500-1000
# 14             NaN             No        No          Never            6-25
# 15             NaN            Yes       Yes         Rarely          26-100
# 16             NaN             No       Yes      Sometimes          26-100
# 17             NaN             No       Yes      Sometimes            6-25
# 18             Yes            Yes        No      Sometimes             1-5
# 19             Yes            Yes        No            NaN            6-25
# 20              No            Yes       Yes      Sometimes         100-500
# 21             Yes             No        No          Never             1-5
# 22              No             No       Yes          Often          26-100
# 23              No             No       Yes          Never  More than 1000
# 24              No            Yes       Yes         Rarely          26-100
# 25              No            Yes       Yes      Sometimes  More than 1000
# 26              No             No        No            NaN             1-5
# 27              No            Yes       Yes         Rarely            6-25
# 28              No             No       Yes      Sometimes          26-100
# 29              No             No        No      Sometimes            6-25
# ...            ...            ...       ...            ...             ...
# 1229            No             No        No            NaN            6-25
# 1230            No            Yes       Yes      Sometimes            6-25
# 1231           Yes             No       Yes      Sometimes            6-25
# 1232            No            Yes       Yes      Sometimes  More than 1000
# 1233            No             No       Yes         Rarely            6-25
# 1234            No             No       Yes      Sometimes            6-25
# 1235            No             No       Yes          Often          26-100
# 1236            No             No       Yes          Often  More than 1000
# 1237            No             No        No      Sometimes          26-100
# 1238            No            Yes       Yes          Often  More than 1000
# 1239            No             No        No      Sometimes        500-1000
# 1240            No            Yes       Yes      Sometimes         100-500
# 1241           Yes             No       Yes          Often            6-25
# 1242            No             No       Yes         Rarely          26-100
# 1243            No            Yes       Yes         Rarely  More than 1000
# 1244            No             No        No            NaN  More than 1000
# 1245            No            Yes       Yes          Often         100-500
# 1246            No             No        No          Never         100-500
# 1247            No             No       Yes          Often            6-25
# 1248            No            Yes       Yes      Sometimes          26-100
# 1249            No            Yes       Yes      Sometimes          26-100
# 1250           Yes            Yes       Yes          Often          26-100
# 1251            No            Yes       Yes          Often         100-500
# 1252            No            Yes       Yes      Sometimes         100-500
# 1253            No            Yes        No         Rarely  More than 1000
# 1254            No             No       Yes            NaN          26-100
# 1255            No            Yes       Yes          Often          26-100
# 1256            No            Yes       Yes      Sometimes  More than 1000
# 1257            No             No        No            NaN         100-500
# 1258            No            Yes       Yes      Sometimes          26-100
#
#                             ...                                       leave  \
# 0                           ...                               Somewhat easy
# 1                           ...                                  Don't know
# 2                           ...                          Somewhat difficult
# 3                           ...                          Somewhat difficult
# 4                           ...                                  Don't know
# 5                           ...                                  Don't know
# 6                           ...                          Somewhat difficult
# 7                           ...                                  Don't know
# 8                           ...                              Very difficult
# 9                           ...                                  Don't know
# 10                          ...                                  Don't know
# 11                          ...                                  Don't know
# 12                          ...                          Somewhat difficult
# 13                          ...                                  Don't know
# 14                          ...                               Somewhat easy
# 15                          ...                               Somewhat easy
# 16                          ...                                   Very easy
# 17                          ...                                  Don't know
# 18                          ...                                   Very easy
# 19                          ...                               Somewhat easy
# 20                          ...                          Somewhat difficult
# 21                          ...                          Somewhat difficult
# 22                          ...                                  Don't know
# 23                          ...                                  Don't know
# 24                          ...                                  Don't know
# 25                          ...                                   Very easy
# 26                          ...                                  Don't know
# 27                          ...                                  Don't know
# 28                          ...                          Somewhat difficult
# 29                          ...                              Very difficult
# ...                         ...                                         ...
# 1229                        ...                                  Don't know
# 1230                        ...                                   Very easy
# 1231                        ...                                  Don't know
# 1232                        ...                                   Very easy
# 1233                        ...                                  Don't know
# 1234                        ...                                  Don't know
# 1235                        ...                                  Don't know
# 1236                        ...                               Somewhat easy
# 1237                        ...                                  Don't know
# 1238                        ...                               Somewhat easy
# 1239                        ...                                  Don't know
# 1240                        ...                               Somewhat easy
# 1241                        ...                               Somewhat easy
# 1242                        ...                                  Don't know
# 1243                        ...                                  Don't know
# 1244                        ...                                  Don't know
# 1245                        ...                                  Don't know
# 1246                        ...                               Somewhat easy
# 1247                        ...                              Very difficult
# 1248                        ...                                  Don't know
# 1249                        ...                                   Very easy
# 1250                        ...                                  Don't know
# 1251                        ...                               Somewhat easy
# 1252                        ...                                  Don't know
# 1253                        ...                               Somewhat easy
# 1254                        ...                               Somewhat easy
# 1255                        ...                          Somewhat difficult
# 1256                        ...                          Somewhat difficult
# 1257                        ...                                  Don't know
# 1258                        ...                                  Don't know
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 0                           No                      No  Some of them
# 1                        Maybe                      No            No
# 2                           No                      No           Yes
# 3                          Yes                     Yes  Some of them
# 4                           No                      No  Some of them
# 5                           No                      No           Yes
# 6                        Maybe                   Maybe  Some of them
# 7                           No                      No            No
# 8                        Maybe                      No           Yes
# 9                           No                      No           Yes
# 10                          No                      No  Some of them
# 11                          No                      No           Yes
# 12                         Yes                     Yes           Yes
# 13                          No                      No           Yes
# 14                          No                      No  Some of them
# 15                          No                      No           Yes
# 16                       Maybe                      No  Some of them
# 17                       Maybe                      No  Some of them
# 18                          No                      No           Yes
# 19                          No                      No  Some of them
# 20                       Maybe                      No  Some of them
# 21                          No                      No  Some of them
# 22                       Maybe                      No  Some of them
# 23                       Maybe                      No            No
# 24                          No                      No           Yes
# 25                         Yes                      No  Some of them
# 26                       Maybe                   Maybe  Some of them
# 27                          No                      No           Yes
# 28                          No                      No  Some of them
# 29                         Yes                   Maybe  Some of them
# ...                        ...                     ...           ...
# 1229                       Yes                      No            No
# 1230                        No                      No           Yes
# 1231                     Maybe                   Maybe  Some of them
# 1232                        No                      No           Yes
# 1233                        No                      No           Yes
# 1234                       Yes                   Maybe            No
# 1235                     Maybe                      No           Yes
# 1236                     Maybe                   Maybe  Some of them
# 1237                       Yes                   Maybe            No
# 1238                       Yes                   Maybe  Some of them
# 1239                     Maybe                      No           Yes
# 1240                        No                      No  Some of them
# 1241                     Maybe                      No  Some of them
# 1242                     Maybe                      No            No
# 1243                        No                      No  Some of them
# 1244                     Maybe                      No  Some of them
# 1245                     Maybe                   Maybe            No
# 1246                        No                      No            No
# 1247                       Yes                      No  Some of them
# 1248                       Yes                   Maybe            No
# 1249                        No                      No           Yes
# 1250                        No                      No  Some of them
# 1251                        No                      No  Some of them
# 1252                       Yes                      No  Some of them
# 1253                     Maybe                   Maybe  Some of them
# 1254                        No                      No  Some of them
# 1255                        No                      No  Some of them
# 1256                       Yes                     Yes            No
# 1257                       Yes                      No            No
# 1258                     Maybe                      No  Some of them
#
#         supervisor mental_health_interview phys_health_interview  \
# 0              Yes                      No                 Maybe
# 1               No                      No                    No
# 2              Yes                     Yes                   Yes
# 3               No                   Maybe                 Maybe
# 4              Yes                     Yes                   Yes
# 5              Yes                      No                 Maybe
# 6               No                      No                    No
# 7               No                      No                    No
# 8              Yes                      No                 Maybe
# 9              Yes                   Maybe                 Maybe
# 10             Yes                      No                    No
# 11             Yes                     Yes                   Yes
# 12             Yes                   Maybe                 Maybe
# 13             Yes                      No                    No
# 14    Some of them                   Maybe                   Yes
# 15    Some of them                   Maybe                 Maybe
# 16              No                   Maybe                 Maybe
# 17             Yes                      No                    No
# 18             Yes                      No                   Yes
# 19    Some of them                   Maybe                 Maybe
# 20    Some of them                      No                    No
# 21    Some of them                      No                 Maybe
# 22             Yes                      No                 Maybe
# 23              No                      No                   Yes
# 24             Yes                      No                   Yes
# 25             Yes                      No                   Yes
# 26              No                      No                    No
# 27             Yes                   Maybe                 Maybe
# 28              No                      No                    No
# 29              No                      No                 Maybe
# ...            ...                     ...                   ...
# 1229            No                      No                    No
# 1230           Yes                   Maybe                 Maybe
# 1231  Some of them                      No                 Maybe
# 1232           Yes                     Yes                   Yes
# 1233           Yes                      No                 Maybe
# 1234            No                      No                 Maybe
# 1235  Some of them                      No                    No
# 1236            No                      No                 Maybe
# 1237            No                      No                    No
# 1238           Yes                      No                    No
# 1239           Yes                   Maybe                   Yes
# 1240            No                      No                    No
# 1241            No                      No                    No
# 1242            No                      No                 Maybe
# 1243           Yes                      No                    No
# 1244           Yes                      No                   Yes
# 1245           Yes                      No                 Maybe
# 1246  Some of them                   Maybe                   Yes
# 1247            No                      No                 Maybe
# 1248            No                      No                    No
# 1249           Yes                   Maybe                 Maybe
# 1250           Yes                   Maybe                 Maybe
# 1251           Yes                      No                   Yes
# 1252            No                      No                 Maybe
# 1253  Some of them                      No                    No
# 1254  Some of them                      No                    No
# 1255           Yes                      No                    No
# 1256            No                      No                    No
# 1257            No                      No                    No
# 1258            No                      No                    No
#
#      mental_vs_physical obs_consequence  \
# 0                   Yes              No
# 1            Don't know              No
# 2                    No              No
# 3                    No             Yes
# 4            Don't know              No
# 5            Don't know              No
# 6            Don't know              No
# 7                    No              No
# 8                    No              No
# 9                   Yes              No
# 10           Don't know              No
# 11           Don't know              No
# 12                   No             Yes
# 13           Don't know              No
# 14                  Yes              No
# 15           Don't know              No
# 16                   No              No
# 17                   No              No
# 18                  Yes             Yes
# 19           Don't know              No
# 20                   No              No
# 21                  Yes              No
# 22                   No              No
# 23           Don't know              No
# 24           Don't know              No
# 25                   No              No
# 26           Don't know              No
# 27                  Yes              No
# 28                   No              No
# 29                   No              No
# ...                 ...             ...
# 1229         Don't know              No
# 1230                Yes              No
# 1231         Don't know             Yes
# 1232                Yes              No
# 1233         Don't know              No
# 1234         Don't know              No
# 1235         Don't know              No
# 1236         Don't know              No
# 1237                 No             Yes
# 1238                 No             Yes
# 1239         Don't know              No
# 1240         Don't know              No
# 1241         Don't know              No
# 1242         Don't know              No
# 1243         Don't know              No
# 1244                 No              No
# 1245         Don't know             Yes
# 1246         Don't know              No
# 1247         Don't know             Yes
# 1248         Don't know              No
# 1249                Yes              No
# 1250                Yes              No
# 1251                Yes              No
# 1252                 No              No
# 1253         Don't know              No
# 1254         Don't know              No
# 1255                Yes              No
# 1256                 No              No
# 1257                 No              No
# 1258         Don't know              No
#
#                                                comments
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13    I'm not on my company's health insurance which...
# 14                                                  NaN
# 15    I have chronic low-level neurological issues t...
# 16    My company does provide healthcare but not to ...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                  Relatively new job. Ask again later
# 25    Sometimes I think  about using drugs for my me...
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1229                                                NaN
# 1230                                                NaN
# 1231                                                NaN
# 1232  I work at a large university with a track reco...
# 1233                                                NaN
# 1234  i'm in a country with social health care so my...
# 1235                                                NaN
# 1236                                                NaN
# 1237                                                NaN
# 1238                                                NaN
# 1239                                                NaN
# 1240                                                NaN
# 1241                                                NaN
# 1242                                                NaN
# 1243                                                NaN
# 1244                                                NaN
# 1245  In australia all organisations of a certain si...
# 1246                                                NaN
# 1247                                                NaN
# 1248                                                NaN
# 1249                                  Bipolar disorder
# 1250                                                NaN
# 1251                                                NaN
# 1252                                                NaN
# 1253                                                NaN
# 1254                                                NaN
# 1255                                                NaN
# 1256                                                NaN
# 1257                                                NaN
# 1258                                                NaN
#
# [1256 rows x 27 columns]

# %%
df['Age'] > 40
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8        True
# 9       False
# 10      False
# 11      False
# 12       True
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22       True
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1229    False
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# 1234    False
# 1235    False
# 1236     True
# 1237    False
# 1238    False
# 1239    False
# 1240    False
# 1241    False
# 1242    False
# 1243     True
# 1244    False
# 1245    False
# 1246    False
# 1247    False
# 1248     True
# 1249    False
# 1250    False
# 1251    False
# 1252    False
# 1253    False
# 1254    False
# 1255    False
# 1256    False
# 1257     True
# 1258    False
# Name: Age, Length: 1259, dtype: bool

# %%
df[  df['Age'] > 40  ]
# Out:
#                 Timestamp  Age      Gender         Country state  \
# 1     2014-08-27 11:29:37   44           M   United States    IN
# 8     2014-08-27 11:32:39   42      Female   United States    IL
# 12    2014-08-27 11:33:23   42      female   United States    CA
# 18    2014-08-27 11:34:53   46        male   United States    MD
# 22    2014-08-27 11:35:48   46        Male   United States    MA
# 23    2014-08-27 11:36:24   41        Male   United States    IA
# 33    2014-08-27 11:39:36   42        Male   United States    WA
# 38    2014-08-27 11:42:08   50           M   United States    IN
# 60    2014-08-27 11:48:57   44        Male   United States    IA
# 101   2014-08-27 12:18:38   44      Female   United States    MA
# 112   2014-08-27 12:31:03   45        male   United States    MO
# 167   2014-08-27 12:48:29   42        male   United States    CA
# 178   2014-08-27 12:51:25   45           F   United States    CA
# 183   2014-08-27 12:51:55   45           M   United States    CA
# 184   2014-08-27 12:52:08   43        Male   United States    WA
# 202   2014-08-27 12:58:10   41        male   United States    FL
# 219   2014-08-27 13:09:39   41  Male (CIS)   United States    VA
# 231   2014-08-27 13:23:38   41        Male   United States    TX
# 257   2014-08-27 13:47:27   42        Male   United States    WA
# 264   2014-08-27 13:53:44   43        Male          Canada   NaN
# 266   2014-08-27 13:54:00   41        Male   United States    AL
# 292   2014-08-27 14:15:13   45        male   United States    NY
# 294   2014-08-27 14:15:57   56        Male   United States   NaN
# 297   2014-08-27 14:18:41   60        male   United States    CA
# 320   2014-08-27 14:28:41   41        Male   United States    SD
# 333   2014-08-27 14:37:33   45        Male         Ireland   NaN
# 335   2014-08-27 14:37:46   46           M   United States    WA
# 347   2014-08-27 14:45:45   54           M   United States    CA
# 364   2014-08-27 15:05:21  329        Male   United States    OH
# 371   2014-08-27 15:20:53   41           m   United States    WA
# ...                   ...  ...         ...             ...   ...
# 1054  2014-08-29 11:39:33   42           M   United States    TN
# 1062  2014-08-29 12:00:33   44           M   United States    FL
# 1068  2014-08-29 12:45:11   48        Male   United States    IN
# 1071  2014-08-29 13:17:33   43        Male   United States    OH
# 1072  2014-08-29 13:23:40   41           M   United States    IL
# 1076  2014-08-29 14:31:00   43        Male   United States    VA
# 1086  2014-08-29 16:51:31   41        male         Germany   NaN
# 1091  2014-08-29 17:32:31   43        male   United States    TX
# 1099  2014-08-29 20:53:58   43        Male   United States    NY
# 1104  2014-08-29 23:51:01   45           M   United States    CA
# 1106  2014-08-30 03:55:19   50        male          France   NaN
# 1117  2014-08-30 15:57:04   46        Male   United States    PA
# 1121  2014-08-30 19:35:58   44        Male  United Kingdom   NaN
# 1123  2014-08-30 20:12:33   45      female   United States    MI
# 1130  2014-08-31 15:03:12   42           F   United States    WA
# 1137  2014-09-01 06:53:28   41           M  United Kingdom   NaN
# 1159  2014-09-03 01:32:51   51           M       Singapore   NaN
# 1164  2014-09-04 23:42:28   46      Female   United States    CA
# 1182  2014-10-02 21:25:16   72      Female   United States    IN
# 1186  2014-11-06 11:24:38   56      female   United States    OR
# 1190  2015-01-03 03:38:30   44           M   United States    OH
# 1211  2015-02-21 09:16:45   45        male         Ireland   NaN
# 1217  2015-02-21 09:30:29   42        male         Ireland   NaN
# 1220  2015-02-21 10:00:50   46        Male   United States    CA
# 1221  2015-02-21 10:45:51   46        male   United States    MD
# 1222  2015-02-21 11:48:52   41      female     Netherlands   NaN
# 1236  2015-02-24 10:32:32   60        Male   United States    CA
# 1243  2015-05-05 14:22:18   43           f   United States    FL
# 1248  2015-06-25 12:24:31   41      Female   United States    WA
# 1257  2015-11-30 21:25:06   46           f   United States    NC
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 1              NaN             No        No         Rarely  More than 1000
# 8              NaN            Yes       Yes      Sometimes         100-500
# 12             NaN            Yes       Yes      Sometimes          26-100
# 18             Yes            Yes        No      Sometimes             1-5
# 22              No             No       Yes          Often          26-100
# 23              No             No       Yes          Never  More than 1000
# 33              No            Yes       Yes      Sometimes          26-100
# 38              No             No        No            NaN         100-500
# 60              No            Yes       Yes      Sometimes  More than 1000
# 101             No             No        No          Never         100-500
# 112             No            Yes       Yes         Rarely            6-25
# 167             No             No        No            NaN            6-25
# 178             No             No       Yes      Sometimes             1-5
# 183             No             No       Yes      Sometimes  More than 1000
# 184             No            Yes       Yes          Often  More than 1000
# 202             No             No       Yes          Often            6-25
# 219             No             No        No            NaN          26-100
# 231             No             No       Yes         Rarely        500-1000
# 257             No             No        No          Never            6-25
# 264            Yes             No        No            NaN            6-25
# 266             No             No       Yes      Sometimes          26-100
# 292             No            Yes       Yes      Sometimes  More than 1000
# 294             No             No       Yes          Never  More than 1000
# 297             No             No        No            NaN  More than 1000
# 320             No            Yes       Yes         Rarely         100-500
# 333            Yes             No       Yes          Often             1-5
# 335             No             No        No          Never          26-100
# 347             No            Yes       Yes          Never  More than 1000
# 364             No             No       Yes          Often            6-25
# 371             No            Yes       Yes          Often  More than 1000
# ...            ...            ...       ...            ...             ...
# 1054            No             No        No         Rarely  More than 1000
# 1062           Yes             No        No          Never             1-5
# 1068            No             No        No          Never          26-100
# 1071            No             No        No      Sometimes  More than 1000
# 1072            No             No        No         Rarely  More than 1000
# 1076           Yes            Yes       Yes      Sometimes             1-5
# 1086            No             No       Yes      Sometimes  More than 1000
# 1091            No            Yes        No          Never         100-500
# 1099            No             No        No          Never        500-1000
# 1104            No             No        No          Never            6-25
# 1106           Yes             No       Yes      Sometimes          26-100
# 1117            No            Yes       Yes      Sometimes            6-25
# 1121            No             No       Yes      Sometimes  More than 1000
# 1123            No             No       Yes         Rarely          26-100
# 1130            No            Yes       Yes      Sometimes          26-100
# 1137            No            Yes        No            NaN            6-25
# 1159            No             No        No          Never  More than 1000
# 1164            No             No       Yes          Often         100-500
# 1182            No            Yes       Yes          Never        500-1000
# 1186           Yes             No        No         Rarely             1-5
# 1190            No            Yes       Yes      Sometimes         100-500
# 1211            No             No        No          Never  More than 1000
# 1217            No             No        No          Never          26-100
# 1220            No            Yes       Yes          Often          26-100
# 1221            No            Yes       Yes      Sometimes         100-500
# 1222           Yes             No       Yes         Rarely             1-5
# 1236            No             No       Yes          Often  More than 1000
# 1243            No            Yes       Yes         Rarely  More than 1000
# 1248            No            Yes       Yes      Sometimes          26-100
# 1257            No             No        No            NaN         100-500
#
#                             ...                                       leave  \
# 1                           ...                                  Don't know
# 8                           ...                              Very difficult
# 12                          ...                          Somewhat difficult
# 18                          ...                                   Very easy
# 22                          ...                                  Don't know
# 23                          ...                                  Don't know
# 33                          ...                                   Very easy
# 38                          ...                                  Don't know
# 60                          ...                                  Don't know
# 101                         ...                                  Don't know
# 112                         ...                                   Very easy
# 167                         ...                              Very difficult
# 178                         ...                          Somewhat difficult
# 183                         ...                                  Don't know
# 184                         ...                              Very difficult
# 202                         ...                              Very difficult
# 219                         ...                                   Very easy
# 231                         ...                                  Don't know
# 257                         ...                               Somewhat easy
# 264                         ...                               Somewhat easy
# 266                         ...                                   Very easy
# 292                         ...                                  Don't know
# 294                         ...                                  Don't know
# 297                         ...                                  Don't know
# 320                         ...                               Somewhat easy
# 333                         ...                              Very difficult
# 335                         ...                                   Very easy
# 347                         ...                                  Don't know
# 364                         ...                                  Don't know
# 371                         ...                          Somewhat difficult
# ...                         ...                                         ...
# 1054                        ...                                  Don't know
# 1062                        ...                          Somewhat difficult
# 1068                        ...                                  Don't know
# 1071                        ...                                  Don't know
# 1072                        ...                                  Don't know
# 1076                        ...                                  Don't know
# 1086                        ...                          Somewhat difficult
# 1091                        ...                               Somewhat easy
# 1099                        ...                                  Don't know
# 1104                        ...                                  Don't know
# 1106                        ...                                  Don't know
# 1117                        ...                                  Don't know
# 1121                        ...                                  Don't know
# 1123                        ...                                  Don't know
# 1130                        ...                                  Don't know
# 1137                        ...                          Somewhat difficult
# 1159                        ...                                  Don't know
# 1164                        ...                                  Don't know
# 1182                        ...                               Somewhat easy
# 1186                        ...                                  Don't know
# 1190                        ...                                  Don't know
# 1211                        ...                                  Don't know
# 1217                        ...                          Somewhat difficult
# 1220                        ...                                  Don't know
# 1221                        ...                                  Don't know
# 1222                        ...                               Somewhat easy
# 1236                        ...                               Somewhat easy
# 1243                        ...                                  Don't know
# 1248                        ...                                  Don't know
# 1257                        ...                                  Don't know
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 1                        Maybe                      No            No
# 8                        Maybe                      No           Yes
# 12                         Yes                     Yes           Yes
# 18                          No                      No           Yes
# 22                       Maybe                      No  Some of them
# 23                       Maybe                      No            No
# 33                       Maybe                      No  Some of them
# 38                          No                      No  Some of them
# 60                         Yes                   Maybe  Some of them
# 101                      Maybe                   Maybe            No
# 112                         No                      No           Yes
# 167                      Maybe                      No           Yes
# 178                         No                      No           Yes
# 183                        Yes                     Yes  Some of them
# 184                        Yes                   Maybe            No
# 202                      Maybe                   Maybe  Some of them
# 219                        Yes                      No            No
# 231                      Maybe                   Maybe  Some of them
# 257                         No                      No  Some of them
# 264                      Maybe                      No           Yes
# 266                         No                      No           Yes
# 292                      Maybe                      No  Some of them
# 294                         No                   Maybe           Yes
# 297                         No                      No  Some of them
# 320                         No                      No  Some of them
# 333                         No                      No            No
# 335                         No                      No  Some of them
# 347                         No                      No            No
# 364                      Maybe                      No  Some of them
# 371                      Maybe                      No           Yes
# ...                        ...                     ...           ...
# 1054                     Maybe                      No  Some of them
# 1062                        No                      No            No
# 1068                     Maybe                      No  Some of them
# 1071                     Maybe                      No            No
# 1072                     Maybe                   Maybe  Some of them
# 1076                     Maybe                   Maybe  Some of them
# 1086                        No                      No           Yes
# 1091                     Maybe                      No  Some of them
# 1099                        No                      No           Yes
# 1104                       Yes                   Maybe  Some of them
# 1106                     Maybe                   Maybe  Some of them
# 1117                       Yes                   Maybe            No
# 1121                     Maybe                      No  Some of them
# 1123                        No                      No  Some of them
# 1130                       Yes                      No  Some of them
# 1137                     Maybe                   Maybe  Some of them
# 1159                       Yes                      No            No
# 1164                     Maybe                      No  Some of them
# 1182                     Maybe                   Maybe  Some of them
# 1186                     Maybe                   Maybe            No
# 1190                     Maybe                      No  Some of them
# 1211                       Yes                      No           Yes
# 1217                       Yes                     Yes  Some of them
# 1220                     Maybe                      No  Some of them
# 1221                        No                      No  Some of them
# 1222                        No                      No           Yes
# 1236                     Maybe                   Maybe  Some of them
# 1243                        No                      No  Some of them
# 1248                       Yes                   Maybe            No
# 1257                       Yes                      No            No
#
#         supervisor mental_health_interview phys_health_interview  \
# 1               No                      No                    No
# 8              Yes                      No                 Maybe
# 12             Yes                   Maybe                 Maybe
# 18             Yes                      No                   Yes
# 22             Yes                      No                 Maybe
# 23              No                      No                   Yes
# 33    Some of them                   Maybe                   Yes
# 38             Yes                      No                 Maybe
# 60              No                      No                 Maybe
# 101   Some of them                      No                    No
# 112            Yes                     Yes                   Yes
# 167            Yes                      No                 Maybe
# 178            Yes                      No                    No
# 183   Some of them                      No                    No
# 184             No                      No                    No
# 202   Some of them                   Maybe                 Maybe
# 219   Some of them                      No                    No
# 231             No                   Maybe                 Maybe
# 257            Yes                      No                    No
# 264            Yes                     Yes                   Yes
# 266            Yes                     Yes                   Yes
# 292   Some of them                      No                 Maybe
# 294   Some of them                      No                 Maybe
# 297            Yes                   Maybe                 Maybe
# 320            Yes                   Maybe                 Maybe
# 333             No                      No                    No
# 335   Some of them                   Maybe                 Maybe
# 347            Yes                      No                    No
# 364             No                      No                    No
# 371   Some of them                      No                 Maybe
# ...            ...                     ...                   ...
# 1054            No                      No                 Maybe
# 1062            No                      No                    No
# 1068           Yes                      No                 Maybe
# 1071            No                      No                    No
# 1072            No                      No                    No
# 1076  Some of them                      No                 Maybe
# 1086           Yes                      No                    No
# 1091  Some of them                      No                 Maybe
# 1099  Some of them                      No                    No
# 1104            No                      No                 Maybe
# 1106           Yes                      No                    No
# 1117  Some of them                      No                 Maybe
# 1121  Some of them                      No                    No
# 1123  Some of them                      No                 Maybe
# 1130  Some of them                      No                   Yes
# 1137  Some of them                   Maybe                 Maybe
# 1159            No                      No                    No
# 1164  Some of them                      No                 Maybe
# 1182           Yes                      No                    No
# 1186            No                      No                    No
# 1190  Some of them                      No                    No
# 1211  Some of them                      No                    No
# 1217  Some of them                      No                    No
# 1220            No                      No                    No
# 1221           Yes                     Yes                   Yes
# 1222           Yes                     Yes                   Yes
# 1236            No                      No                 Maybe
# 1243           Yes                      No                    No
# 1248            No                      No                    No
# 1257            No                      No                    No
#
#      mental_vs_physical obs_consequence  \
# 1            Don't know              No
# 8                    No              No
# 12                   No             Yes
# 18                  Yes             Yes
# 22                   No              No
# 23           Don't know              No
# 33           Don't know              No
# 38           Don't know              No
# 60           Don't know             Yes
# 101          Don't know              No
# 112                 Yes              No
# 167                  No              No
# 178                 Yes              No
# 183          Don't know              No
# 184                  No              No
# 202          Don't know              No
# 219          Don't know              No
# 231                  No              No
# 257                 Yes              No
# 264          Don't know              No
# 266                 Yes              No
# 292          Don't know              No
# 294          Don't know              No
# 297                 Yes              No
# 320                 Yes              No
# 333          Don't know              No
# 335          Don't know              No
# 347          Don't know              No
# 364                  No              No
# 371                  No             Yes
# ...                 ...             ...
# 1054                 No              No
# 1062         Don't know              No
# 1068         Don't know              No
# 1071         Don't know              No
# 1072                Yes             Yes
# 1076         Don't know              No
# 1086                Yes              No
# 1091                 No              No
# 1099                Yes              No
# 1104         Don't know              No
# 1106         Don't know              No
# 1117         Don't know              No
# 1121                 No              No
# 1123         Don't know              No
# 1130                 No              No
# 1137         Don't know              No
# 1159                 No              No
# 1164                 No              No
# 1182         Don't know             Yes
# 1186         Don't know              No
# 1190         Don't know              No
# 1211                 No             Yes
# 1217                 No              No
# 1220                 No              No
# 1221         Don't know              No
# 1222                Yes              No
# 1236         Don't know              No
# 1243         Don't know              No
# 1248         Don't know              No
# 1257                 No              No
#
#                                                comments
# 1                                                   NaN
# 8                                                   NaN
# 12                                                  NaN
# 18                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 33    I selected my current employer based on its po...
# 38                                                  NaN
# 60                                                  NaN
# 101                                                 NaN
# 112                                                 NaN
# 167                                                 NaN
# 178   In small startups it is very hard to keep ment...
# 183                                                 NaN
# 184                                                 NaN
# 202                                                 NaN
# 219                                                 NaN
# 231   I found it difficult to answer all of the ques...
# 257   No benefits at this organization but my employ...
# 264                                                 NaN
# 266   I think I am very lucky in my workplace. Our C...
# 292                                                 NaN
# 294                                                 NaN
# 297                                                 NaN
# 320                                                 NaN
# 333                                                 NaN
# 335                                                 NaN
# 347                                                 NaN
# 364                                                 NaN
# 371                                                 NaN
# ...                                                 ...
# 1054                                                NaN
# 1062                                                NaN
# 1068                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1076  This survey was tough as a self-employed indiv...
# 1086                                                NaN
# 1091                                                NaN
# 1099                                                NaN
# 1104                                                NaN
# 1106                                                NaN
# 1117                                                NaN
# 1121                                                NaN
# 1123                                                NaN
# 1130                                                NaN
# 1137                                                NaN
# 1159                                                NaN
# 1164                                                NaN
# 1182                                                NaN
# 1186  I'm self-employed on contract with small start...
# 1190  My mental health issues were the direct result...
# 1211                                                NaN
# 1217                                                NaN
# 1220                                                NaN
# 1221  Just starting a new job hence the numerous I d...
# 1222  The data will be skewed for self-employed peop...
# 1236                                                NaN
# 1243                                                NaN
# 1248                                                NaN
# 1257                                                NaN
#
# [150 rows x 27 columns]

# %% [markdown]
# ### Example: Find people who reported a family history of mental health conditions. </font>

# %% [markdown]
# Solution:

# %%
family_history_mask = df.family_history=='Yes'
df[family_history_mask].tail(5)
# Out:
#                 Timestamp  Age Gender        Country state self_employed  \
# 1252  2015-08-20 16:52:09   29   male  United States    NC            No
# 1253  2015-08-25 19:59:38   36   Male  United States    UT            No
# 1255  2015-09-26 01:07:35   32   Male  United States    IL            No
# 1256  2015-11-07 12:36:58   34   male  United States    CA            No
# 1258  2016-02-01 23:04:31   25   Male  United States    IL            No
#
#      family_history treatment work_interfere    no_employees   ...     \
# 1252            Yes       Yes      Sometimes         100-500   ...
# 1253            Yes        No         Rarely  More than 1000   ...
# 1255            Yes       Yes          Often          26-100   ...
# 1256            Yes       Yes      Sometimes  More than 1000   ...
# 1258            Yes       Yes      Sometimes          26-100   ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# 1252          Don't know                       Yes                      No
# 1253       Somewhat easy                     Maybe                   Maybe
# 1255  Somewhat difficult                        No                      No
# 1256  Somewhat difficult                       Yes                     Yes
# 1258          Don't know                     Maybe                      No
#
#          coworkers    supervisor mental_health_interview  \
# 1252  Some of them            No                      No
# 1253  Some of them  Some of them                      No
# 1255  Some of them           Yes                      No
# 1256            No            No                      No
# 1258  Some of them            No                      No
#
#      phys_health_interview mental_vs_physical obs_consequence comments
# 1252                 Maybe                 No              No      NaN
# 1253                    No         Don't know              No      NaN
# 1255                    No                Yes              No      NaN
# 1256                    No                 No              No      NaN
# 1258                    No         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# You can use a simple expression like ```df[df['family_history'] == 'Yes']``` or you can make more complex boolean expressions using parentheses:

# %%
df_filtered = df[(df['family_history'] == 'Yes') & (df['treatment'] == 'Yes')]
df_filtered.head()
# Out:
#               Timestamp  Age  Gender         Country state self_employed  \
# 3   2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 6   2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 8   2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 12  2014-08-27 11:33:23   42  female   United States    CA           NaN
# 15  2014-08-27 11:34:00   29  female   United States    IL           NaN
#
#    family_history treatment work_interfere no_employees  \
# 3             Yes       Yes          Often       26-100
# 6             Yes       Yes      Sometimes          1-5
# 8             Yes       Yes      Sometimes      100-500
# 12            Yes       Yes      Sometimes       26-100
# 15            Yes       Yes         Rarely       26-100
#
#                           ...                                       leave  \
# 3                         ...                          Somewhat difficult
# 6                         ...                          Somewhat difficult
# 8                         ...                              Very difficult
# 12                        ...                          Somewhat difficult
# 15                        ...                               Somewhat easy
#
#    mental_health_consequence phys_health_consequence     coworkers  \
# 3                        Yes                     Yes  Some of them
# 6                      Maybe                   Maybe  Some of them
# 8                      Maybe                      No           Yes
# 12                       Yes                     Yes           Yes
# 15                        No                      No           Yes
#
#       supervisor mental_health_interview phys_health_interview  \
# 3             No                   Maybe                 Maybe
# 6             No                      No                    No
# 8            Yes                      No                 Maybe
# 12           Yes                   Maybe                 Maybe
# 15  Some of them                   Maybe                 Maybe
#
#    mental_vs_physical obs_consequence  \
# 3                  No             Yes
# 6          Don't know              No
# 8                  No              No
# 12                 No             Yes
# 15         Don't know              No
#
#                                              comments
# 3                                                 NaN
# 6                                                 NaN
# 8                                                 NaN
# 12                                                NaN
# 15  I have chronic low-level neurological issues t...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### <font color="red">Q1: How many people are willing to discuss a mental health issue with their supervisor or their coworkers? </font>

# %%
df_filtered = df[(df['coworkers'] == 'Yes') | (df['supervisor'] == 'Yes')]
len(df_filtered)
# Out:
# 546

# %% [markdown]
# ### <font color="red">Q2: Make a new DataFrame ```df_millenials``` with only millennials (born between 1976 and 1996). Make appropriate assumptions when constructing your filter. </font>

# %%
df_millenials = df[(df['Age'] <= 38) & (df['Age'] >= 18)]
df_millenials.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
# 5  2014-08-27 11:31:22   33    Male   United States    TN           NaN
#
#   family_history treatment work_interfere no_employees   ...     \
# 0             No       Yes          Often         6-25   ...
# 2             No        No         Rarely         6-25   ...
# 3            Yes       Yes          Often       26-100   ...
# 4             No        No          Never      100-500   ...
# 5            Yes        No      Sometimes         6-25   ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
# 5          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
# 5           Yes        Yes                      No                 Maybe
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
# 5         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# **NOTE: We will still use df for the following analysis**

# %% [markdown]
# ## Descriptive and Summary Statistics

# %% [markdown]
# Example: What is the mean age of the survey sample?

# %% [markdown]
# Solution:

# %%
df['Age'].mean()
# Out:
# 79428148.31135821

# %% [markdown]
# ### Does that look right?  What should we do?

# %% [markdown]
# ### <font color="red">Q3: What is the _median_ age of the survey sample?  </font>

# %%
df['Age'].median()
# Out:
# 31.0

# %% [markdown]
# ### <font color="red">Q4: Write one line of code to compute basic statistics (mean, standard deviation, min, 25% percentile, etc) about Age  </font>
#
# Hint: see the readings

# %%
df['Age'].describe()
# Out:
# count    1.259000e+03
# mean     7.942815e+07
# std      2.818299e+09
# min     -1.726000e+03
# 25%      2.700000e+01
# 50%      3.100000e+01
# 75%      3.600000e+01
# max      1.000000e+11
# Name: Age, dtype: float64

# %% [markdown]
# ## Unique Values, Counts, Membership

# %% [markdown]
# Example: Write one line of code to check unique values of Gender</font>

# %% [markdown]
# Solution:

# %%
df.coworkers.unique()
# Out:
# array(['Some of them', 'No', 'Yes'], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %% [markdown]
# Example: Write one line of code to count the occurrences of the countries and show the top 5 countries.  </font>

# %% [markdown]
# Solution:

# %%
df.Country.value_counts().head(5)
# Out:
# United States     751
# United Kingdom    185
# Canada             72
# Germany            45
# Ireland            27
# Name: Country, dtype: int64

# %% [markdown]
# Are you sure that's correct?

# %% [markdown]
# ### <font color="red">Q5: Find the unique categories of no_employees. What is the frequency of each category? </font>

# %%
df.no_employees.value_counts()
# Out:
# 6-25              290
# 26-100            289
# More than 1000    282
# 100-500           176
# 1-5               162
# 500-1000           60
# Name: no_employees, dtype: int64

# %% [markdown]
# ### <font color="red">Q6: How many Michiganders aged between 20 and 30 sought treatment for a mental health condition? How many did not? </font>
# Show your code and also include a markdown block with a complete sentence or two that answers these questions.

# %%
df_q6 = df[(df['Age'] >= 20) & (df['Age'] <= 30) & (df['treatment'] == 'Yes') & (df['state'] == 'MI')]
print("Seek: ", len(df_q6))
df_q6 = df[(df['Age'] >= 20) & (df['Age'] <= 30) & (df['treatment'] != 'Yes') & (df['state'] == 'MI')]
print("Not seek: ", len(df_q6))
# Out:
# Seek:  5
# Not seek:  3

# %% [markdown]
# Replace this with you answer

# %% [markdown]
# ### <font color="red">Q7: Among the people from United States, how many repondents were there from each state?  </font>

# %%
df_q7 = df[(df['Country'] >= 'United States')]
df_q7.state.value_counts()
# Out:
# CA    138
# WA     70
# NY     56
# TN     45
# TX     44
# OH     30
# PA     29
# OR     29
# IL     28
# IN     27
# MI     22
# MN     21
# MA     20
# FL     15
# NC     14
# VA     14
# WI     12
# GA     12
# MO     12
# UT     10
# CO      9
# AL      8
# AZ      7
# MD      7
# NJ      6
# OK      6
# KY      5
# SC      5
# DC      4
# IA      4
# CT      4
# NV      3
# NH      3
# KS      3
# VT      3
# SD      3
# WY      2
# NE      2
# NM      2
# ID      1
# ME      1
# MS      1
# RI      1
# LA      1
# WV      1
# Name: state, dtype: int64

# %% [markdown]
# ## Basic Plots

# %% [markdown]
# Example: Investigate the proportion (%) of people receiving health benefits from their employers.

# %% [markdown]
# Solution:

# %%
df.benefits.value_counts(normalize=True).plot.bar()

# %% [markdown]
# Example: Create a histogram of the distribution of Age values:

# %%
df.Age.value_counts().plot.hist()

# %% [markdown]
# ### <font color="red">Q8: Experiment with the number of bins in the histogram of the Age distribution:</font>

# %% [markdown]
# Hint: use the bins= option to plot()

# %%
df.Age.value_counts().plot.hist(bins = 5)

# %% [markdown]
# ## Discretization and Binning
# Discretization of continuous variables can potentially enhance the goodness-of-fit of a statistical model. Age, for example, is a common varaible to be categorized.
#
# ### <font color="red">Q9: </font> Discretize the age into bins (16,21], (21,25], (25,30], (30, 35], (35,40], (40,50], (50,60], (60,).
#
# How many respondents are in each range?
# Hint: create a list of bin values
# Hint: use pd.cut()
# Hint: use value_counts()

# %%
bins = [15,20,25,30,35,40,50,60,200]

# %%
pd.cut(df['Age'], bins).value_counts()
# Out:
# (25, 30]     362
# (30, 35]     339
# (20, 25]     195
# (35, 40]     185
# (40, 50]     122
# (50, 60]      22
# (15, 20]      22
# (60, 200]      4
# Name: Age, dtype: int64

# %% [markdown]
# ## Aggregation

# %% [markdown]
# Example: Find the size of each Age group.

# %% [markdown]
# Solution:

# %%
df.groupby('Age').size()
# Out:
# Age
# -1726            1
# -29              1
# -1               1
#  5               1
#  8               1
#  11              1
#  18              7
#  19              9
#  20              6
#  21             16
#  22             21
#  23             51
#  24             46
#  25             61
#  26             75
#  27             71
#  28             68
#  29             85
#  30             63
#  31             67
#  32             82
#  33             70
#  34             65
#  35             55
#  36             37
#  37             43
#  38             39
#  39             33
#  40             33
#  41             21
#  42             20
#  43             28
#  44             11
#  45             12
#  46             12
#  47              2
#  48              6
#  49              4
#  50              6
#  51              5
#  53              1
#  54              3
#  55              3
#  56              4
#  57              3
#  58              1
#  60              2
#  61              1
#  62              1
#  65              1
#  72              1
#  329             1
#  99999999999     1
# dtype: int64

# %% [markdown]
# ### <font color="red">Q10: Find the median age of each state. </font>

# %%
pd.DataFrame(df,columns=['state', 'Age']).groupby('state').median()
# Out:
#         Age
# state
# AL     34.0
# AZ     33.0
# CA     31.0
# CO     31.0
# CT     37.5
# DC     37.5
# FL     34.0
# GA     30.0
# IA     40.0
# ID     55.0
# IL     30.0
# IN     34.0
# KS     39.0
# KY     24.0
# LA     35.0
# MA     32.0
# MD     29.0
# ME     40.0
# MI     34.0
# MN     30.0
# MO     33.5
# MS     33.0
# NC     32.0
# NE     26.0
# NH     34.0
# NJ     32.0
# NM     29.5
# NV     28.0
# NY     29.0
# OH     31.0
# OK     26.5
# OR     32.0
# PA     31.0
# RI     23.0
# SC     30.0
# SD     34.0
# TN     33.0
# TX     31.5
# UT     28.0
# VA     40.5
# VT     34.0
# WA     32.5
# WI     33.0
# WV     23.0
# WY     41.5

# %% [markdown]
# # Part 2 (on your own): Exploration of Movie Titles and Movie Cast

# %% [markdown]
# ## Time to load some data:

# %%
titles = pd.read_csv('data/titles.csv', index_col=None)

# %% [markdown]
# The titles DataFrame contains a list of movie titles and release year

# %%
cast = pd.read_csv('data/cast.zip', index_col=None)

# %% [markdown]
# The ```cast``` DataFrame contains the following columns
#
# **title** = name of movie
#
# **year** = year of movie
#
# **name** = name of actor/actress
#
# **type** = actor or actress
#
# **character** = character name
#
# **n** = number in the credits (NaN when not available)

# %%
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast.sample(5)
# Out:
#                              title  year                  name     type  \
# 2783024              Tire au flanc  1928       Fridette Fatton  actress
# 1991174         The Primitive Call  1917           Lewis Sealy    actor
# 812680   Le avventure di Mary Read  1961           Loris Gizzi    actor
# 2069496    Inexplicable Epiphanies  2013  Warren (XXIII) Smith    actor
# 3170968     Man elsker kun en gang  1945       Randi Michelsen  actress
#
#                character     n
# 2783024        Georgette  11.0
# 1991174     John Malcolm   5.0
# 812680   Prison Director  14.0
# 2069496           Deputy  15.0
# 3170968       Olga Ish?j   4.0

# %% [markdown]
# ### Q11: How many entries are there in the cast table?

# %%
len(cast)
# Out:
# 3634467

# %% [markdown]
# ### Q12: How many entries are there in the titles table?

# %%
len(titles)
# Out:
# 232330

# %% [markdown]
# ## Some basic analyses

# %% [markdown]
# ### Q13: What are the two earliest movies?

# %%
df_q13 = titles.sort_values('year')
df_q13.head(2)
# Out:
#                      title  year
# 177757          Miss Jerry  1894
# 215272  The Startled Lover  1898

# %% [markdown]
# ### Q14: How many movies have the title "Hamlet"?

# %%
df_q14 = titles[(titles['title'] == 'Hamlet')]
len(df_q14)
# Out:
# 18

# %% [markdown]
# ### Q15: List all of the "Treasure Island" movies from earliest to most recent

# %%
df_q15 = titles[(titles['title'] == 'Treasure Island')].sort_values('year')
df_q15
# Out:
#                   title  year
# 206027  Treasure Island  1918
# 51287   Treasure Island  1920
# 191050  Treasure Island  1934
# 96934   Treasure Island  1950
# 89534   Treasure Island  1972
# 111343  Treasure Island  1973
# 205397  Treasure Island  1985
# 179354  Treasure Island  1999

# %% [markdown]
# ### Q16: List the supporting roles (having n=2) played by Cary Grant in the 1940s,
# in order by year.

# %%
#(cast.year >= 1940) & (cast.year < 1950)
#(cast.year == 1940) | (cast.year == 1941)... 
# cast.year // 10 == 194
df_q16 = cast[(cast['n'] == 2) & (cast['year']//10 == 194) & (cast['name'] == 'Cary Grant')]
df_q16
# Out:
#                    title  year        name   type    character    n
# 845513  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 845523    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### Q17: What are the ten most common movie names of all time?

# %%
titles.title.value_counts().head(10)
# Out:
# Hamlet                  18
# Carmen                  16
# Macbeth                 15
# Maya                    12
# The Outsider            12
# The Three Musketeers    11
# Temptation              11
# Kismet                  11
# Freedom                 11
# Othello                 11
# Name: title, dtype: int64

# %% [markdown]
# ### Q18: Plot the number of "Hamlet" films made each decade
#
# Make sure your decades are in chronological order on the x-axis

# %%
bins = list(range(1900,2030,10))

df_q18 = titles[(titles['title'] == 'Hamlet')]

pd.cut(df_q18['year'], bins).value_counts().sort_index().plot.bar()

# %% [markdown]
# ### Q19: Who are the 10 people most often credited as "Herself" in film history?

# %%
cast[cast['character'] == 'Herself'].name.value_counts().head(10)
# Out:
# Queen Elizabeth II    11
# Joyce Brothers         9
# Margaret Thatcher      8
# Hillary Clinton        7
# Mary Jo Pehl           7
# Sumie Sakai            6
# Joan Rivers            6
# Kareena Kapoor         5
# Bunny Yeager           5
# Rekha                  5
# Name: name, dtype: int64

# %% [markdown]
# ### Q20: What are the 10 most frequent roles that start with the word "Science"?
# Hint: read docs on str.startswith()

# %%
cast[cast['character'].str.startswith('Science')].character.value_counts().head(10)
# Out:
# Science Teacher         60
# Science Student          9
# Science Fair Student     9
# Science Fair Judge       6
# Science Reporter         5
# Science Kid              5
# Science Club Member      5
# Science Promo Cadet      5
# Science                  4
# Science Officer          3
# Name: character, dtype: int64

# %% [markdown]
# ### Q21: How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
print(len(cast[(cast['type']=='actor') & (cast['n']==1) & (cast['year']//10==195)]))
print(len(cast[(cast['type']=='actress') & (cast['n']==1) & (cast['year']//10==195)]))
# Out:
# 6616
# 2965

# %% [markdown]
# ### Q22: How many supporting (n=2) roles were available to actors,and how many to actresses, in the 1950s?

# %%
print(len(cast[(cast['type']=='actor') & (cast['n']==2) & (cast['year']//10==195)]))
print(len(cast[(cast['type']=='actress') & (cast['n']==2) & (cast['year']//10==195)]))
# Out:
# 4564
# 4556

# %% [markdown]
# ### Q23: Comment on the differences in gender ratios for leading vs. supporting roles in the 1950s.  Does there appear to be a bias?

# %%
#Yes, women tend to be supporting roles instead of leading roles back in the 1950s. There is some gender bias.
